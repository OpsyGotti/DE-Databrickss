# %%
# %fs ls /Volumes/course_ws_practise/default/olist

# %%
# Read CSV file dbfs:/Volumes/course_ws_practise/default/olist/olist_customers_dataset.csv
df = spark.read.csv("dbfs:/Volumes/course_ws_practise/default/olist/olist_customers_dataset.csv", header=True, inferSchema=True)
display(df)

# %%
# read data from external location abfss://dbfs-container@opsygottipractice.dfs.core.windows.net/landing_zone/archive
df = spark.read.csv("abfss://dbfs-container@opsygottipractice.dfs.core.windows.net/landing_zone/archive", header=True, inferSchema=True)
display(df)

# %%
# %fs ls abfss://dbfs-container@opsygottipractice.dfs.core.windows.net/landing_zone/archive

# %%
# read delta table course_ws_practise.default.olist_customers_dataset
df = spark.read.table("course_ws_practise.default.olist_customers_dataset")
display(df)
